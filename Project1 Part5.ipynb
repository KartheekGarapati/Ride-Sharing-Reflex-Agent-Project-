# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# Parameters
n_nodes = 100  # Number of nodes
degree = 3     # Connectivity degree

# Generate a random regular graph
G = nx.random_regular_graph(degree, n_nodes)

# Assign weights to the edges
# Weight 2 for congested roads, weight 1 for non-congested roads
for u, v in G.edges():
    # Randomly assign weights: 1 (non-congested) or 2 (congested)
    G[u][v]['weight'] = random.choice([1, 2])

# Check if the graph is connected
if nx.is_connected(G):
    print("Graph is connected")
else:
    print("Graph is not connected")

# Draw the graph with weighted edges
edge_colors = ['red' if G[u][v]['weight'] == 2 else 'green' for u, v in G.edges()]
pos = nx.spring_layout(G)  # Position nodes for better visualization

plt.figure(figsize=(10, 10))
nx.draw(G, pos, node_color='skyblue', with_labels=True, node_size=500, font_size=8, edge_color=edge_colors)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()
# Out:
# Graph is connected

# %%
nx.is_connected(G)      # check whether G which has at least one path between each pair of nodes.
# Out:
# True

# %%
#R5
import networkx as nx
import random
from collections import deque

# Global waiting list
waiting_list = []

# Define the vehicle and customer classes
class Vehicle:
    def __init__(self, vehicle_id):
        self.id = vehicle_id
        self.queue = deque()  # List of customers in the vehicle (FIFO)
        self.path = []        # Route the vehicle is taking
        self.current_node = None  # Current position of the vehicle
        self.completed_customers = []  # Store customers who have been picked up and dropped off

    def add_customer(self, customer):
        self.queue.append(customer)

class Customer:
    def __init__(self, pickup, dropoff, request_time):
        self.pickup = pickup
        self.dropoff = dropoff
        self.request_time = request_time
        self.pickup_time = None
        self.dropoff_time = None

# Generate a random customer request
def generate_reservation(time):
    pickup = random.randint(0, 99)  # Random pickup node
    dropoff = random.randint(0, 99)  # Random dropoff node
    while dropoff == pickup:
        dropoff = random.randint(0, 99)  # Ensure dropoff is different
    return Customer(pickup, dropoff, time)

# Assign a customer to an available vehicle
def assign_vehicle(customer, vehicles):
    # Find the first available vehicle (that is not full)
    for vehicle in vehicles:
        if len(vehicle.queue) < 5:  # Assuming the vehicle can hold 5 customers
            vehicle.add_customer(customer)
            return
    # If no vehicle is available, add the customer to a waiting list
    print(f"No available vehicles for customer at time {customer.request_time}, added to waiting list")
    waiting_list.append(customer)

# Process the waiting list and assign customers to vehicles
def process_waiting_list(vehicles):
    global waiting_list  # Access the global waiting list
    for customer in waiting_list[:]:  # Copy the list to modify it during iteration
        for vehicle in vehicles:
            if len(vehicle.queue) < 5:  # Check if the vehicle has space
                vehicle.add_customer(customer)
                waiting_list.remove(customer)
                break  # Assign one customer at a time to available vehicles

# Process vehicle movement and drop off customers
def process_vehicle_movement(vehicle, clock):
    # Ensure vehicle's path is initialized as a list
    if vehicle.path is None:
        vehicle.path = []

    # Check if the vehicle has a customer and no path
    if not vehicle.path and vehicle.queue:
        next_customer = vehicle.queue[0]
        # If this is the first time the customer is being picked up, record pickup time
        if next_customer.pickup_time is None:
            next_customer.pickup_time = clock
            print(f"Customer picked up at time {clock} by Vehicle {vehicle.id}")

        # Calculate the shortest path to the customer's dropoff location
        try:
            vehicle.path = nx.shortest_path(G, vehicle.current_node, next_customer.dropoff, weight='weight')
            if isinstance(vehicle.path, list):
                print(f"Vehicle {vehicle.id} moving along path: {vehicle.path}")
            else:
                print(f"Error: Expected a list, but got {type(vehicle.path)}. Path: {vehicle.path}")
        except nx.NetworkXNoPath:
            print(f"No path found for vehicle {vehicle.id} to customer {next_customer.dropoff}")
            return  # If no path is found, stop processing for this tick

    # If the path is still empty (no valid path), do nothing
    if not vehicle.path:
        print(f"Vehicle {vehicle.id} has no path at clock {clock}")
        return

    # Move along the path one step
    next_node = vehicle.path.pop(0)  # Safely pop the next node from the list
    vehicle.current_node = next_node

    # Check if any customer needs to be dropped off at this node
    for customer in list(vehicle.queue):
        if customer.dropoff == vehicle.current_node:
            print(f"Dropping off customer at {vehicle.current_node} at time {clock}")
            vehicle.queue.remove(customer)
            customer.dropoff_time = clock  # Record the dropoff time
            vehicle.completed_customers.append(customer)  # Track completed customers

# Simulate a day of operations without Vehicle 0
def simulate_day():
    clock = 0
    # Exclude Vehicle 0 by starting the list from Vehicle 1 (ID 1 to 29)
    vehicles = [Vehicle(i) for i in range(1, 60)]
    total_reservations = random.randint(450, 600) * 10
    global G
    G = nx.random_regular_graph(6, 100)  # Generate a random regular graph with 100 nodes and degree 6

    # Assign weights (1 or 2) to the edges to simulate congestion
    for (u, v) in G.edges():
        G.edges[u, v]['weight'] = random.choice([1, 2])

    # Start the simulation from 8 AM to 6 PM (10 hours)
    while clock < 10 * 60 or any(vehicle.queue for vehicle in vehicles) or waiting_list:
        if clock < 10 * 60:  # During service hours
            for _ in range(total_reservations // 600):  # Generate reservations each minute
                customer = generate_reservation(clock)
                assign_vehicle(customer, vehicles)

        # Process waiting list
        process_waiting_list(vehicles)

        # Move vehicles and process customer drop-offs
        for vehicle in vehicles:
            if vehicle.queue:
                if vehicle.current_node is None:  # Assign a random starting node if not set
                    vehicle.current_node = random.randint(0, 99)
                process_vehicle_movement(vehicle, clock)

            # Display service queues (S) and routing queues (P)
            service_queue = [(c.pickup, c.dropoff) for c in vehicle.queue]  # Pickup and dropoff points
            print(f"Clock {clock}: Vehicle {vehicle.id} Service Queue (S): {service_queue}")
            print(f"Clock {clock}: Vehicle {vehicle.id} Routing Path (P): {vehicle.path}")

        clock += 1  # Increment clock

    return vehicles

# Compute performance metrics
def compute_metrics(vehicles):
    total_waiting_time = 0
    total_service_time = 0
    total_trips = 0

    # Iterate over all completed customers across vehicles
    for vehicle in vehicles:
        for customer in vehicle.completed_customers:
            # Ensure both pickup and dropoff times are recorded before calculating
            if customer.pickup_time is not None and customer.dropoff_time is not None:
                total_waiting_time += customer.pickup_time - customer.request_time
                total_service_time += customer.dropoff_time - customer.pickup_time
                total_trips += 1

    avg_waiting_time = total_waiting_time / total_trips if total_trips > 0 else 0
    avg_service_time = total_service_time / total_trips if total_trips > 0 else 0
    avg_trips = total_trips / len(vehicles) if len(vehicles) > 0 else 0

    return avg_waiting_time, avg_service_time, avg_trips

# Step 1: Run the simulation (without Vehicle 0)
vehicles = simulate_day()  # This now excludes Vehicle 0 (starts from Vehicle 1)

# Step 2: Calculate metrics
avg_waiting_time, avg_service_time, avg_trips = compute_metrics(vehicles)

# Step 3: Output the results
print(f"Average Waiting Time: {avg_waiting_time}")
print(f"Average Service Time: {avg_service_time}")
print(f"Average Trips per Day: {avg_trips}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Clock 585: Vehicle 9 Service Queue (S): [(71, 22), (2, 95), (51, 14), (83, 33), (31, 77)]
# Clock 585: Vehicle 9 Routing Path (P): [20, 22]
# Customer picked up at time 585 by Vehicle 10
# Vehicle 10 moving along path: [47, 97, 50]
# Clock 585: Vehicle 10 Service Queue (S): [(80, 50), (85, 14), (81, 19), (9, 66), (46, 1)]
# Clock 585: Vehicle 10 Routing Path (P): [97, 50]
# Clock 585: Vehicle 11 Service Queue (S): [(73, 48), (70, 19), (4, 65), (41, 98), (13, 71)]
# Clock 585: Vehicle 11 Routing Path (P): [48]
# Customer picked up at time 585 by Vehicle 12
# Vehicle 12 moving along path: [70, 62, 16]
# Clock 585: Vehicle 12 Service Queue (S): [(87, 16), (48, 55), (23, 73), (75, 91), (26, 11)]
# Clock 585: Vehicle 12 Routing Path (P): [62, 16]
# Clock 585: Vehicle 13 Service Queue (S): [(82, 8), (28, 41), (10, 24), (28, 88), (90, 98)]
# Clock 585: Vehicle 13 Routing Path (P): [8]
# Dropping off customer at 68 at time 585
# Clock 585: Vehicle 14 Service Queue (S): [(60, 50), (99, 54), (54, 36), (34, 32)]
# Clock 585: Vehicle 14 Routing Path (P): []
# Clock 585: Vehicle 15 Service Queue (S): [(2, 0), (8, 32), (33, 97), (98, 32), (63, 51)]
# Clock 585: Vehicle 15 Routing Path (P): [0]
# Customer picked up at time 585 by Vehicle 16
# Vehicle 16 moving along path: [83, 36, 71, 0, 81]
# Clock 585: Vehicle 16 Service Queue (S): [(33, 81), (79, 66), (8, 36), (0, 40), (69, 77)]
# Clock 585: Vehicle 16 Routing Path (P): [36, 71, 0, 81]
# Dropping off customer at 79 at time 585
# Clock 585: Vehicle 17 Service Queue (S): [(18, 35), (82, 92), (8, 82), (21, 43)]
# Clock 585: Vehicle 17 Routing Path (P): []
# Customer picked up at time 585 by Vehicle 18
# Vehicle 18 moving along path: [43, 81, 88]
# Clock 585: Vehicle 18 Service Queue (S): [(84, 88), (37, 90), (5, 39), (92, 72), (38, 42)]
# Clock 585: Vehicle 18 Routing Path (P): [81, 88]
# Dropping off customer at 96 at time 585
# Clock 585: Vehicle 19 Service Queue (S): [(53, 7), (7, 19), (54, 59), (0, 67)]
# Clock 585: Vehicle 19 Routing Path (P): []
# Dropping off customer at 28 at time 585
# Clock 585: Vehicle 20 Service Queue (S): [(77, 34), (56, 92), (84, 4), (22, 7)]
# Clock 585: Vehicle 20 Routing Path (P): []
# Clock 585: Vehicle 21 Service Queue (S): [(31, 18), (65, 53), (39, 51), (35, 5), (36, 96)]
# Clock 585: Vehicle 21 Routing Path (P): [18]
# Customer picked up at time 585 by Vehicle 22
# Vehicle 22 moving along path: [71, 0, 57]
# Clock 585: Vehicle 22 Service Queue (S): [(45, 57), (52, 23), (74, 91), (11, 95), (61, 77)]
# Clock 585: Vehicle 22 Routing Path (P): [0, 57]
# Customer picked up at time 585 by Vehicle 23
# Vehicle 23 moving along path: [81, 0, 71, 5]
# Clock 585: Vehicle 23 Service Queue (S): [(29, 5), (27, 31), (15, 90), (33, 52), (29, 99)]
# Clock 585: Vehicle 23 Routing Path (P): [0, 71, 5]
# Dropping off customer at 50 at time 585
# Clock 585: Vehicle 24 Service Queue (S): [(41, 71), (51, 5), (0, 33), (12, 74)]
# Clock 585: Vehicle 24 Routing Path (P): [71]
# Customer picked up at time 585 by Vehicle 25
# Vehicle 25 moving along path: [97, 47, 68]
# Clock 585: Vehicle 25 Service Queue (S): [(27, 68), (95, 28), (48, 17), (87, 67), (81, 94)]
# Clock 585: Vehicle 25 Routing Path (P): [47, 68]
# Customer picked up at time 585 by Vehicle 26
# Vehicle 26 moving along path: [43, 76]
# Clock 585: Vehicle 26 Service Queue (S): [(18, 76), (18, 23), (14, 23), (27, 90)]
# Clock 585: Vehicle 26 Routing Path (P): [76]
# Clock 585: Vehicle 27 Service Queue (S): [(69, 97), (31, 14), (96, 90), (64, 80), (63, 60)]
# Clock 585: Vehicle 27 Routing Path (P): [9, 97]
# Dropping off customer at 39 at time 585
# Clock 585: Vehicle 28 Service Queue (S): [(62, 69), (26, 63), (61, 3), (84, 53)]
# Clock 585: Vehicle 28 Routing Path (P): []
# Customer picked up at time 585 by Vehicle 29
# Vehicle 29 moving along path: [45, 7, 88]
# Clock 585: Vehicle 29 Service Queue (S): [(9, 88), (29, 75), (77, 71), (16, 57)]
# Clock 585: Vehicle 29 Routing Path (P): [7, 88]
# Clock 585: Vehicle 30 Service Queue (S): [(99, 39), (19, 43), (19, 87), (13, 70), (44, 58)]
# Clock 585: Vehicle 30 Routing Path (P): [39]
# Clock 585: Vehicle 31 Service Queue (S): [(34, 30), (84, 49), (28, 35), (53, 58), (85, 28)]
# Clock 585: Vehicle 31 Routing Path (P): [30]
# Clock 585: Vehicle 32 Service Queue (S): [(34, 96), (38, 0), (16, 13), (36, 34), (89, 6)]
# Clock 585: Vehicle 32 Routing Path (P): [62, 96]
# Clock 585: Vehicle 33 Service Queue (S): [(38, 26), (17, 55), (94, 17)]
# Clock 585: Vehicle 33 Routing Path (P): [52, 62, 26]
# Clock 585: Vehicle 34 Service Queue (S): []
# Clock 585: Vehicle 34 Routing Path (P): []
# Clock 585: Vehicle 35 Service Queue (S): []
# Clock 585: Vehicle 35 Routing Path (P): []
# Clock 585: Vehicle 36 Service Queue (S): []
# Clock 585: Vehicle 36 Routing Path (P): []
# Clock 585: Vehicle 37 Service Queue (S): []
# Clock 585: Vehicle 37 Routing Path (P): []
# Clock 585: Vehicle 38 Service Queue (S): []
# Clock 585: Vehicle 38 Routing Path (P): []
# Clock 585: Vehicle 39 Service Queue (S): []
# Clock 585: Vehicle 39 Routing Path (P): []
# Clock 585: Vehicle 40 Service Queue (S): []
# Clock 585: Vehicle 40 Routing Path (P): []
# Clock 585: Vehicle 41 Service Queue (S): []
# Clock 585: Vehicle 41 Routing Path (P): []
# Clock 585: Vehicle 42 Service Queue (S): []
# Clock 585: Vehicle 42 Routing Path (P): []
# Clock 585: Vehicle 43 Service Queue (S): []
# Clock 585: Vehicle 43 Routing Path (P): []
# Clock 585: Vehicle 44 Service Queue (S): []
# Clock 585: Vehicle 44 Routing Path (P): []
# Clock 585: Vehicle 45 Service Queue (S): []
# Clock 585: Vehicle 45 Routing Path (P): []
# Clock 585: Vehicle 46 Service Queue (S): []
# Clock 585: Vehicle 46 Routing Path (P): []
# Clock 585: Vehicle 47 Service Queue (S): []
# Clock 585: Vehicle 47 Routing Path (P): []
# Clock 585: Vehicle 48 Service Queue (S): []
# Clock 585: Vehicle 48 Routing Path (P): []
# Clock 585: Vehicle 49 Service Queue (S): []
# Clock 585: Vehicle 49 Routing Path (P): []
# Clock 585: Vehicle 50 Service Queue (S): []
# Clock 585: Vehicle 50 Routing Path (P): []
# Clock 585: Vehicle 51 Service Queue (S): []
# Clock 585: Vehicle 51 Routing Path (P): []
# Clock 585: Vehicle 52 Service Queue (S): []
# Clock 585: Vehicle 52 Routing Path (P): []
# Clock 585: Vehicle 53 Service Queue (S): []
# Clock 585: Vehicle 53 Routing Path (P): []
# Clock 585: Vehicle 54 Service Queue (S): []
# Clock 585: Vehicle 54 Routing Path (P): []
# Clock 585: Vehicle 55 Service Queue (S): []
# Clock 585: Vehicle 55 Routing Path (P): []
# Clock 585: Vehicle 56 Service Queue (S): []
# Clock 585: Vehicle 56 Routing Path (P): []
# Clock 585: Vehicle 57 Service Queue (S): []
# Clock 585: Vehicle 57 Routing Path (P): []
# Clock 585: Vehicle 58 Service Queue (S): []
# Clock 585: Vehicle 58 Routing Path (P): []
# Clock 585: Vehicle 59 Service Queue (S): []
# Clock 585: Vehicle 59 Routing Path (P): []
# Dropping off customer at 39 at time 586
# Clock 586: Vehicle 1 Service Queue (S): [(39, 84), (55, 83), (55, 5), (43, 90)]
# Clock 586: Vehicle 1 Routing Path (P): []
# Clock 586: Vehicle 2 Service Queue (S): [(76, 46), (32, 82), (95, 97), (89, 79), (47, 51)]
# Clock 586: Vehicle 2 Routing Path (P): [46]
# Clock 586: Vehicle 3 Service Queue (S): [(91, 7), (35, 97), (39, 94), (94, 72), (2, 38)]
# Clock 586: Vehicle 3 Routing Path (P): [7]
# Dropping off customer at 63 at time 586
# Clock 586: Vehicle 4 Service Queue (S): [(83, 42), (77, 43), (71, 96), (15, 50)]
# Clock 586: Vehicle 4 Routing Path (P): []
# Clock 586: Vehicle 5 Service Queue (S): [(89, 50), (79, 98), (3, 54), (76, 94), (32, 79)]
# Clock 586: Vehicle 5 Routing Path (P): [50]
# Clock 586: Vehicle 6 Service Queue (S): [(31, 40), (95, 90), (95, 55), (65, 76), (80, 60)]
# Clock 586: Vehicle 6 Routing Path (P): [40]
# Customer picked up at time 586 by Vehicle 7
# Vehicle 7 moving along path: [1, 5, 71, 36]
# Clock 586: Vehicle 7 Service Queue (S): [(37, 36), (42, 54), (9, 36), (33, 72), (73, 0)]
# Clock 586: Vehicle 7 Routing Path (P): [5, 71, 36]
# Customer picked up at time 586 by Vehicle 8
# Vehicle 8 moving along path: [5, 72, 54, 47, 68]
# Clock 586: Vehicle 8 Service Queue (S): [(2, 68), (71, 8), (2, 30), (41, 11), (89, 93)]
# Clock 586: Vehicle 8 Routing Path (P): [72, 54, 47, 68]
# Clock 586: Vehicle 9 Service Queue (S): [(71, 22), (2, 95), (51, 14), (83, 33), (31, 77)]
# Clock 586: Vehicle 9 Routing Path (P): [22]
# Clock 586: Vehicle 10 Service Queue (S): [(80, 50), (85, 14), (81, 19), (9, 66), (46, 1)]
# Clock 586: Vehicle 10 Routing Path (P): [50]
# Dropping off customer at 48 at time 586
# Clock 586: Vehicle 11 Service Queue (S): [(70, 19), (4, 65), (41, 98), (13, 71)]
# Clock 586: Vehicle 11 Routing Path (P): []
# Clock 586: Vehicle 12 Service Queue (S): [(87, 16), (48, 55), (23, 73), (75, 91), (26, 11)]
# Clock 586: Vehicle 12 Routing Path (P): [16]
# Dropping off customer at 8 at time 586
# Clock 586: Vehicle 13 Service Queue (S): [(28, 41), (10, 24), (28, 88), (90, 98)]
# Clock 586: Vehicle 13 Routing Path (P): []
# Customer picked up at time 586 by Vehicle 14
# Vehicle 14 moving along path: [68, 47, 97, 50]
# Clock 586: Vehicle 14 Service Queue (S): [(60, 50), (99, 54), (54, 36), (34, 32), (61, 66)]
# Clock 586: Vehicle 14 Routing Path (P): [47, 97, 50]
# Dropping off customer at 0 at time 586
# Clock 586: Vehicle 15 Service Queue (S): [(8, 32), (33, 97), (98, 32), (63, 51)]
# Clock 586: Vehicle 15 Routing Path (P): []
# Dropping off customer at 36 at time 586
# Clock 586: Vehicle 16 Service Queue (S): [(33, 81), (79, 66), (0, 40), (69, 77)]
# Clock 586: Vehicle 16 Routing Path (P): [71, 0, 81]
# Customer picked up at time 586 by Vehicle 17
# Vehicle 17 moving along path: [79, 85, 35]
# Clock 586: Vehicle 17 Service Queue (S): [(18, 35), (82, 92), (8, 82), (21, 43), (19, 40)]
# Clock 586: Vehicle 17 Routing Path (P): [85, 35]
# Clock 586: Vehicle 18 Service Queue (S): [(84, 88), (37, 90), (5, 39), (92, 72), (38, 42)]
# Clock 586: Vehicle 18 Routing Path (P): [88]
# Customer picked up at time 586 by Vehicle 19
# Vehicle 19 moving along path: [96, 3, 65, 7]
# Clock 586: Vehicle 19 Service Queue (S): [(53, 7), (7, 19), (54, 59), (0, 67), (74, 13)]
# Clock 586: Vehicle 19 Routing Path (P): [3, 65, 7]
# Customer picked up at time 586 by Vehicle 20
# Vehicle 20 moving along path: [28, 34]
# Clock 586: Vehicle 20 Service Queue (S): [(77, 34), (56, 92), (84, 4), (22, 7), (65, 2)]
# Clock 586: Vehicle 20 Routing Path (P): [34]
# Dropping off customer at 18 at time 586
# Clock 586: Vehicle 21 Service Queue (S): [(65, 53), (39, 51), (35, 5), (36, 96)]
# Clock 586: Vehicle 21 Routing Path (P): []
# Clock 586: Vehicle 22 Service Queue (S): [(45, 57), (52, 23), (74, 91), (11, 95), (61, 77)]
# Clock 586: Vehicle 22 Routing Path (P): [57]
# Clock 586: Vehicle 23 Service Queue (S): [(29, 5), (27, 31), (15, 90), (33, 52), (29, 99)]
# Clock 586: Vehicle 23 Routing Path (P): [71, 5]
# Dropping off customer at 71 at time 586
# Clock 586: Vehicle 24 Service Queue (S): [(51, 5), (0, 33), (12, 74), (92, 32)]
# Clock 586: Vehicle 24 Routing Path (P): []
# Clock 586: Vehicle 25 Service Queue (S): [(27, 68), (95, 28), (48, 17), (87, 67), (81, 94)]
# Clock 586: Vehicle 25 Routing Path (P): [68]
# Dropping off customer at 76 at time 586
# Clock 586: Vehicle 26 Service Queue (S): [(18, 23), (14, 23), (27, 90), (46, 29)]
# Clock 586: Vehicle 26 Routing Path (P): []
# Clock 586: Vehicle 27 Service Queue (S): [(69, 97), (31, 14), (96, 90), (64, 80), (63, 60)]
# Clock 586: Vehicle 27 Routing Path (P): [97]
# Customer picked up at time 586 by Vehicle 28
# Vehicle 28 moving along path: [39, 38, 69]
# Clock 586: Vehicle 28 Service Queue (S): [(62, 69), (26, 63), (61, 3), (84, 53), (94, 3)]
# Clock 586: Vehicle 28 Routing Path (P): [38, 69]
# Clock 586: Vehicle 29 Service Queue (S): [(9, 88), (29, 75), (77, 71), (16, 57)]
# Clock 586: Vehicle 29 Routing Path (P): [88]
# Dropping off customer at 39 at time 586
# Clock 586: Vehicle 30 Service Queue (S): [(19, 43), (19, 87), (13, 70), (44, 58)]
# Clock 586: Vehicle 30 Routing Path (P): []
# Dropping off customer at 30 at time 586
# Clock 586: Vehicle 31 Service Queue (S): [(84, 49), (28, 35), (53, 58), (85, 28)]
# Clock 586: Vehicle 31 Routing Path (P): []
# Clock 586: Vehicle 32 Service Queue (S): [(34, 96), (38, 0), (16, 13), (36, 34), (89, 6)]
# Clock 586: Vehicle 32 Routing Path (P): [96]
# Clock 586: Vehicle 33 Service Queue (S): [(38, 26), (17, 55), (94, 17)]
# Clock 586: Vehicle 33 Routing Path (P): [62, 26]
# Clock 586: Vehicle 34 Service Queue (S): []
# Clock 586: Vehicle 34 Routing Path (P): []
# Clock 586: Vehicle 35 Service Queue (S): []
# Clock 586: Vehicle 35 Routing Path (P): []
# Clock 586: Vehicle 36 Service Queue (S): []
# Clock 586: Vehicle 36 Routing Path (P): []
# Clock 586: Vehicle 37 Service Queue (S): []
# Clock 586: Vehicle 37 Routing Path (P): []
# Clock 586: Vehicle 38 Service Queue (S): []
# Clock 586: Vehicle 38 Routing Path (P): []
# Clock 586: Vehicle 39 Service Queue (S): []
# Clock 586: Vehicle 39 Routing Path (P): []
# Clock 586: Vehicle 40 Service Queue (S): []
# Clock 586: Vehicle 40 Routing Path (P): []
# Clock 586: Vehicle 41 Service Queue (S): []
# Clock 586: Vehicle 41 Routing Path (P): []
# Clock 586: Vehicle 42 Service Queue (S): []
# Clock 586: Vehicle 42 Routing Path (P): []
# Clock 586: Vehicle 43 Service Queue (S): []
# Clock 586: Vehicle 43 Routing Path (P): []
# Clock 586: Vehicle 44 Service Queue (S): []
# Clock 586: Vehicle 44 Routing Path (P): []
# Clock 586: Vehicle 45 Service Queue (S): []
# Clock 586: Vehicle 45 Routing Path (P): []
# Clock 586: Vehicle 46 Service Queue (S): []
# Clock 586: Vehicle 46 Routing Path (P): []
# Clock 586: Vehicle 47 Service Queue (S): []
# Clock 586: Vehicle 47 Routing Path (P): []
# Clock 586: Vehicle 48 Service Queue (S): []
# Clock 586: Vehicle 48 Routing Path (P): []
# Clock 586: Vehicle 49 Service Queue (S): []
# Clock 586: Vehicle 49 Routing Path (P): []
# Clock 586: Vehicle 50 Service Queue (S): []
# Clock 586: Vehicle 50 Routing Path (P): []
# Clock 586: Vehicle 51 Service Queue (S): []
# Clock 586: Vehicle 51 Routing Path (P): []
# Clock 586: Vehicle 52 Service Queue (S): []
# Clock 586: Vehicle 52 Routing Path (P): []
# Clock 586: Vehicle 53 Service Queue (S): []
# Clock 586: Vehicle 53 Routing Path (P): []
# Clock 586: Vehicle 54 Service Queue (S): []
# Clock 586: Vehicle 54 Routing Path (P): []
# Clock 586: Vehicle 55 Service Queue (S): []
# Clock 586: Vehicle 55 Routing Path (P): []
# Clock 586: Vehicle 56 Service Queue (S): []
# Clock 586: Vehicle 56 Routing Path (P): []
# Clock 586: Vehicle 57 Service Queue (S): []
# Clock 586: Vehicle 57 Routing Path (P): []
# Clock 586: Vehicle 58 Service Queue (S): []
# Clock 586: Vehicle 58 Routing Path (P): []
# Clock 586: Vehicle 59 Service Queue (S): []
# Clock 586: Vehicle 59 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 1
# Vehicle 1 moving along path: [39, 32, 84]
# Clock 587: Vehicle 1 Service Queue (S): [(39, 84), (55, 83), (55, 5), (43, 90), (66, 27)]
# Clock 587: Vehicle 1 Routing Path (P): [32, 84]
# Dropping off customer at 46 at time 587
# Clock 587: Vehicle 2 Service Queue (S): [(32, 82), (95, 97), (89, 79), (47, 51)]
# Clock 587: Vehicle 2 Routing Path (P): []
# Dropping off customer at 7 at time 587
# Clock 587: Vehicle 3 Service Queue (S): [(35, 97), (39, 94), (94, 72), (2, 38)]
# Clock 587: Vehicle 3 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 4
# Vehicle 4 moving along path: [63, 10, 33, 42]
# Clock 587: Vehicle 4 Service Queue (S): [(83, 42), (77, 43), (71, 96), (15, 50), (48, 54)]
# Clock 587: Vehicle 4 Routing Path (P): [10, 33, 42]
# Dropping off customer at 50 at time 587
# Clock 587: Vehicle 5 Service Queue (S): [(79, 98), (3, 54), (76, 94), (32, 79)]
# Clock 587: Vehicle 5 Routing Path (P): []
# Dropping off customer at 40 at time 587
# Clock 587: Vehicle 6 Service Queue (S): [(95, 90), (95, 55), (65, 76), (80, 60)]
# Clock 587: Vehicle 6 Routing Path (P): []
# Clock 587: Vehicle 7 Service Queue (S): [(37, 36), (42, 54), (9, 36), (33, 72), (73, 0)]
# Clock 587: Vehicle 7 Routing Path (P): [71, 36]
# Clock 587: Vehicle 8 Service Queue (S): [(2, 68), (71, 8), (2, 30), (41, 11), (89, 93)]
# Clock 587: Vehicle 8 Routing Path (P): [54, 47, 68]
# Dropping off customer at 22 at time 587
# Clock 587: Vehicle 9 Service Queue (S): [(2, 95), (51, 14), (83, 33), (31, 77)]
# Clock 587: Vehicle 9 Routing Path (P): []
# Dropping off customer at 50 at time 587
# Clock 587: Vehicle 10 Service Queue (S): [(85, 14), (81, 19), (9, 66), (46, 1)]
# Clock 587: Vehicle 10 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 11
# Vehicle 11 moving along path: [48, 19]
# Clock 587: Vehicle 11 Service Queue (S): [(70, 19), (4, 65), (41, 98), (13, 71), (90, 69)]
# Clock 587: Vehicle 11 Routing Path (P): [19]
# Dropping off customer at 16 at time 587
# Clock 587: Vehicle 12 Service Queue (S): [(48, 55), (23, 73), (75, 91), (26, 11)]
# Clock 587: Vehicle 12 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 13
# Vehicle 13 moving along path: [8, 84, 67, 37, 41]
# Clock 587: Vehicle 13 Service Queue (S): [(28, 41), (10, 24), (28, 88), (90, 98), (98, 50)]
# Clock 587: Vehicle 13 Routing Path (P): [84, 67, 37, 41]
# Clock 587: Vehicle 14 Service Queue (S): [(60, 50), (99, 54), (54, 36), (34, 32), (61, 66)]
# Clock 587: Vehicle 14 Routing Path (P): [97, 50]
# Customer picked up at time 587 by Vehicle 15
# Vehicle 15 moving along path: [0, 46, 31, 99, 32]
# Clock 587: Vehicle 15 Service Queue (S): [(8, 32), (33, 97), (98, 32), (63, 51), (30, 14)]
# Clock 587: Vehicle 15 Routing Path (P): [46, 31, 99, 32]
# Clock 587: Vehicle 16 Service Queue (S): [(33, 81), (79, 66), (0, 40), (69, 77), (98, 50)]
# Clock 587: Vehicle 16 Routing Path (P): [0, 81]
# Clock 587: Vehicle 17 Service Queue (S): [(18, 35), (82, 92), (8, 82), (21, 43), (19, 40)]
# Clock 587: Vehicle 17 Routing Path (P): [35]
# Dropping off customer at 88 at time 587
# Clock 587: Vehicle 18 Service Queue (S): [(37, 90), (5, 39), (92, 72), (38, 42)]
# Clock 587: Vehicle 18 Routing Path (P): []
# Clock 587: Vehicle 19 Service Queue (S): [(53, 7), (7, 19), (54, 59), (0, 67), (74, 13)]
# Clock 587: Vehicle 19 Routing Path (P): [65, 7]
# Dropping off customer at 34 at time 587
# Clock 587: Vehicle 20 Service Queue (S): [(56, 92), (84, 4), (22, 7), (65, 2)]
# Clock 587: Vehicle 20 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 21
# Vehicle 21 moving along path: [18, 54, 53]
# Clock 587: Vehicle 21 Service Queue (S): [(65, 53), (39, 51), (35, 5), (36, 96), (29, 50)]
# Clock 587: Vehicle 21 Routing Path (P): [54, 53]
# Dropping off customer at 57 at time 587
# Clock 587: Vehicle 22 Service Queue (S): [(52, 23), (74, 91), (11, 95), (61, 77)]
# Clock 587: Vehicle 22 Routing Path (P): []
# Clock 587: Vehicle 23 Service Queue (S): [(29, 5), (27, 31), (15, 90), (33, 52), (29, 99)]
# Clock 587: Vehicle 23 Routing Path (P): [5]
# Customer picked up at time 587 by Vehicle 24
# Vehicle 24 moving along path: [71, 5]
# Clock 587: Vehicle 24 Service Queue (S): [(51, 5), (0, 33), (12, 74), (92, 32), (47, 49)]
# Clock 587: Vehicle 24 Routing Path (P): [5]
# Dropping off customer at 68 at time 587
# Clock 587: Vehicle 25 Service Queue (S): [(95, 28), (48, 17), (87, 67), (81, 94)]
# Clock 587: Vehicle 25 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 26
# Vehicle 26 moving along path: [76, 59, 93, 34, 23]
# Clock 587: Vehicle 26 Service Queue (S): [(18, 23), (14, 23), (27, 90), (46, 29), (10, 97)]
# Clock 587: Vehicle 26 Routing Path (P): [59, 93, 34, 23]
# Dropping off customer at 97 at time 587
# Clock 587: Vehicle 27 Service Queue (S): [(31, 14), (96, 90), (64, 80), (63, 60)]
# Clock 587: Vehicle 27 Routing Path (P): []
# Clock 587: Vehicle 28 Service Queue (S): [(62, 69), (26, 63), (61, 3), (84, 53), (94, 3)]
# Clock 587: Vehicle 28 Routing Path (P): [69]
# Dropping off customer at 88 at time 587
# Clock 587: Vehicle 29 Service Queue (S): [(29, 75), (77, 71), (16, 57)]
# Clock 587: Vehicle 29 Routing Path (P): []
# Customer picked up at time 587 by Vehicle 30
# Vehicle 30 moving along path: [39, 38, 69, 43]
# Clock 587: Vehicle 30 Service Queue (S): [(19, 43), (19, 87), (13, 70), (44, 58)]
# Clock 587: Vehicle 30 Routing Path (P): [38, 69, 43]
# Customer picked up at time 587 by Vehicle 31
# Vehicle 31 moving along path: [30, 82, 85, 87, 49]
# Clock 587: Vehicle 31 Service Queue (S): [(84, 49), (28, 35), (53, 58), (85, 28)]
# Clock 587: Vehicle 31 Routing Path (P): [82, 85, 87, 49]
# Dropping off customer at 96 at time 587
# Clock 587: Vehicle 32 Service Queue (S): [(38, 0), (16, 13), (36, 34), (89, 6)]
# Clock 587: Vehicle 32 Routing Path (P): []
# Clock 587: Vehicle 33 Service Queue (S): [(38, 26), (17, 55), (94, 17)]
# Clock 587: Vehicle 33 Routing Path (P): [26]
# Clock 587: Vehicle 34 Service Queue (S): []
# Clock 587: Vehicle 34 Routing Path (P): []
# Clock 587: Vehicle 35 Service Queue (S): []
# Clock 587: Vehicle 35 Routing Path (P): []
# Clock 587: Vehicle 36 Service Queue (S): []
# Clock 587: Vehicle 36 Routing Path (P): []
# Clock 587: Vehicle 37 Service Queue (S): []
# Clock 587: Vehicle 37 Routing Path (P): []
# Clock 587: Vehicle 38 Service Queue (S): []
# Clock 587: Vehicle 38 Routing Path (P): []
# Clock 587: Vehicle 39 Service Queue (S): []
# Clock 587: Vehicle 39 Routing Path (P): []
# Clock 587: Vehicle 40 Service Queue (S): []
# Clock 587: Vehicle 40 Routing Path (P): []
# Clock 587: Vehicle 41 Service Queue (S): []
# Clock 587: Vehicle 41 Routing Path (P): []
# Clock 587: Vehicle 42 Service Queue (S): []
# Clock 587: Vehicle 42 Routing Path (P): []
# Clock 587: Vehicle 43 Service Queue (S): []
# Clock 587: Vehicle 43 Routing Path (P): []
# Clock 587: Vehicle 44 Service Queue (S): []
# Clock 587: Vehicle 44 Routing Path (P): []
# Clock 587: Vehicle 45 Service Queue (S): []
# Clock 587: Vehicle 45 Routing Path (P): []
# Clock 587: Vehicle 46 Service Queue (S): []
# Clock 587: Vehicle 46 Routing Path (P): []
# Clock 587: Vehicle 47 Service Queue (S): []
# Clock 587: Vehicle 47 Routing Path (P): []
# Clock 587: Vehicle 48 Service Queue (S): []
# Clock 587: Vehicle 48 Routing Path (P): []
# Clock 587: Vehicle 49 Service Queue (S): []
# Clock 587: Vehicle 49 Routing Path (P): []
# Clock 587: Vehicle 50 Service Queue (S): []
# Clock 587: Vehicle 50 Routing Path (P): []
# Clock 587: Vehicle 51 Service Queue (S): []
# Clock 587: Vehicle 51 Routing Path (P): []
# Clock 587: Vehicle 52 Service Queue (S): []
# Clock 587: Vehicle 52 Routing Path (P): []
# Clock 587: Vehicle 53 Service Queue (S): []
# Clock 587: Vehicle 53 Routing Path (P): []
# Clock 587: Vehicle 54 Service Queue (S): []
# Clock 587: Vehicle 54 Routing Path (P): []
# Clock 587: Vehicle 55 Service Queue (S): []
# Clock 587: Vehicle 55 Routing Path (P): []
# Clock 587: Vehicle 56 Service Queue (S): []
# Clock 587: Vehicle 56 Routing Path (P): []
# Clock 587: Vehicle 57 Service Queue (S): []
# Clock 587: Vehicle 57 Routing Path (P): []
# Clock 587: Vehicle 58 Service Queue (S): []
# Clock 587: Vehicle 58 Routing Path (P): []
# Clock 587: Vehicle 59 Service Queue (S): []
# Clock 587: Vehicle 59 Routing Path (P): []
# Clock 588: Vehicle 1 Service Queue (S): [(39, 84), (55, 83), (55, 5), (43, 90), (66, 27)]
# Clock 588: Vehicle 1 Routing Path (P): [84]
# Customer picked up at time 588 by Vehicle 2
# Vehicle 2 moving along path: [46, 26, 83, 82]
# Clock 588: Vehicle 2 Service Queue (S): [(32, 82), (95, 97), (89, 79), (47, 51), (97, 91)]
# Clock 588: Vehicle 2 Routing Path (P): [26, 83, 82]
# Customer picked up at time 588 by Vehicle 3
# Vehicle 3 moving along path: [7, 65, 52, 9, 97]
# Clock 588: Vehicle 3 Service Queue (S): [(35, 97), (39, 94), (94, 72), (2, 38), (83, 28)]
# Clock 588: Vehicle 3 Routing Path (P): [65, 52, 9, 97]
# Clock 588: Vehicle 4 Service Queue (S): [(83, 42), (77, 43), (71, 96), (15, 50), (48, 54)]
# Clock 588: Vehicle 4 Routing Path (P): [33, 42]
# Customer picked up at time 588 by Vehicle 5
# Vehicle 5 moving along path: [50, 94, 6, 98]
# Clock 588: Vehicle 5 Service Queue (S): [(79, 98), (3, 54), (76, 94), (32, 79), (32, 88)]
# Clock 588: Vehicle 5 Routing Path (P): [94, 6, 98]
# Customer picked up at time 588 by Vehicle 6
# Vehicle 6 moving along path: [40, 60, 15, 90]
# Clock 588: Vehicle 6 Service Queue (S): [(95, 90), (95, 55), (65, 76), (80, 60), (83, 36)]
# Clock 588: Vehicle 6 Routing Path (P): [60, 15, 90]
# Clock 588: Vehicle 7 Service Queue (S): [(37, 36), (42, 54), (9, 36), (33, 72), (73, 0)]
# Clock 588: Vehicle 7 Routing Path (P): [36]
# Clock 588: Vehicle 8 Service Queue (S): [(2, 68), (71, 8), (2, 30), (41, 11), (89, 93)]
# Clock 588: Vehicle 8 Routing Path (P): [47, 68]
# Customer picked up at time 588 by Vehicle 9
# Vehicle 9 moving along path: [22, 20, 13, 5, 95]
# Clock 588: Vehicle 9 Service Queue (S): [(2, 95), (51, 14), (83, 33), (31, 77), (55, 37)]
# Clock 588: Vehicle 9 Routing Path (P): [20, 13, 5, 95]
# Customer picked up at time 588 by Vehicle 10
# Vehicle 10 moving along path: [50, 15, 60, 14]
# Clock 588: Vehicle 10 Service Queue (S): [(85, 14), (81, 19), (9, 66), (46, 1), (27, 49)]
# Clock 588: Vehicle 10 Routing Path (P): [15, 60, 14]
# Dropping off customer at 19 at time 588
# Clock 588: Vehicle 11 Service Queue (S): [(4, 65), (41, 98), (13, 71), (90, 69)]
# Clock 588: Vehicle 11 Routing Path (P): []
# Customer picked up at time 588 by Vehicle 12
# Vehicle 12 moving along path: [16, 87, 85, 31, 55]
# Clock 588: Vehicle 12 Service Queue (S): [(48, 55), (23, 73), (75, 91), (26, 11), (87, 54)]
# Clock 588: Vehicle 12 Routing Path (P): [87, 85, 31, 55]
# Clock 588: Vehicle 13 Service Queue (S): [(28, 41), (10, 24), (28, 88), (90, 98), (98, 50)]
# Clock 588: Vehicle 13 Routing Path (P): [67, 37, 41]
# Clock 588: Vehicle 14 Service Queue (S): [(60, 50), (99, 54), (54, 36), (34, 32), (61, 66)]
# Clock 588: Vehicle 14 Routing Path (P): [50]
# Clock 588: Vehicle 15 Service Queue (S): [(8, 32), (33, 97), (98, 32), (63, 51), (30, 14)]
# Clock 588: Vehicle 15 Routing Path (P): [31, 99, 32]
# Clock 588: Vehicle 16 Service Queue (S): [(33, 81), (79, 66), (0, 40), (69, 77), (98, 50)]
# Clock 588: Vehicle 16 Routing Path (P): [81]
# Dropping off customer at 35 at time 588
# Clock 588: Vehicle 17 Service Queue (S): [(82, 92), (8, 82), (21, 43), (19, 40)]
# Clock 588: Vehicle 17 Routing Path (P): []
# Customer picked up at time 588 by Vehicle 18
# Vehicle 18 moving along path: [88, 25, 17, 90]
# Clock 588: Vehicle 18 Service Queue (S): [(37, 90), (5, 39), (92, 72), (38, 42), (61, 16)]
# Clock 588: Vehicle 18 Routing Path (P): [25, 17, 90]
# Clock 588: Vehicle 19 Service Queue (S): [(53, 7), (7, 19), (54, 59), (0, 67), (74, 13)]
# Clock 588: Vehicle 19 Routing Path (P): [7]
# Customer picked up at time 588 by Vehicle 20
# Vehicle 20 moving along path: [34, 23, 35, 11, 92]
# Clock 588: Vehicle 20 Service Queue (S): [(56, 92), (84, 4), (22, 7), (65, 2), (70, 78)]
# Clock 588: Vehicle 20 Routing Path (P): [23, 35, 11, 92]
# Clock 588: Vehicle 21 Service Queue (S): [(65, 53), (39, 51), (35, 5), (36, 96), (29, 50)]
# Clock 588: Vehicle 21 Routing Path (P): [53]
# Customer picked up at time 588 by Vehicle 22
# Vehicle 22 moving along path: [57, 93, 34, 23]
# Clock 588: Vehicle 22 Service Queue (S): [(52, 23), (74, 91), (11, 95), (61, 77)]
# Clock 588: Vehicle 22 Routing Path (P): [93, 34, 23]
# Dropping off customer at 5 at time 588
# Clock 588: Vehicle 23 Service Queue (S): [(27, 31), (15, 90), (33, 52), (29, 99)]
# Clock 588: Vehicle 23 Routing Path (P): []
# Dropping off customer at 5 at time 588
# Clock 588: Vehicle 24 Service Queue (S): [(0, 33), (12, 74), (92, 32), (47, 49)]
# Clock 588: Vehicle 24 Routing Path (P): []
# Customer picked up at time 588 by Vehicle 25
# Vehicle 25 moving along path: [68, 79, 75, 28]
# Clock 588: Vehicle 25 Service Queue (S): [(95, 28), (48, 17), (87, 67), (81, 94)]
# Clock 588: Vehicle 25 Routing Path (P): [79, 75, 28]
# Clock 588: Vehicle 26 Service Queue (S): [(18, 23), (14, 23), (27, 90), (46, 29), (10, 97)]
# Clock 588: Vehicle 26 Routing Path (P): [93, 34, 23]
# Customer picked up at time 588 by Vehicle 27
# Vehicle 27 moving along path: [97, 2, 14]
# Clock 588: Vehicle 27 Service Queue (S): [(31, 14), (96, 90), (64, 80), (63, 60)]
# Clock 588: Vehicle 27 Routing Path (P): [2, 14]
# Dropping off customer at 69 at time 588
# Clock 588: Vehicle 28 Service Queue (S): [(26, 63), (61, 3), (84, 53), (94, 3)]
# Clock 588: Vehicle 28 Routing Path (P): []
# Customer picked up at time 588 by Vehicle 29
# Vehicle 29 moving along path: [88, 78, 28, 75]
# Clock 588: Vehicle 29 Service Queue (S): [(29, 75), (77, 71), (16, 57)]
# Clock 588: Vehicle 29 Routing Path (P): [78, 28, 75]
# Clock 588: Vehicle 30 Service Queue (S): [(19, 43), (19, 87), (13, 70), (44, 58)]
# Clock 588: Vehicle 30 Routing Path (P): [69, 43]
# Clock 588: Vehicle 31 Service Queue (S): [(84, 49), (28, 35), (53, 58), (85, 28)]
# Clock 588: Vehicle 31 Routing Path (P): [85, 87, 49]
# Customer picked up at time 588 by Vehicle 32
# Vehicle 32 moving along path: [96, 3, 46, 0]
# Clock 588: Vehicle 32 Service Queue (S): [(38, 0), (16, 13), (36, 34), (89, 6)]
# Clock 588: Vehicle 32 Routing Path (P): [3, 46, 0]
# Dropping off customer at 26 at time 588
# Clock 588: Vehicle 33 Service Queue (S): [(17, 55), (94, 17)]
# Clock 588: Vehicle 33 Routing Path (P): []
# Clock 588: Vehicle 34 Service Queue (S): []
# Clock 588: Vehicle 34 Routing Path (P): []
# Clock 588: Vehicle 35 Service Queue (S): []
# Clock 588: Vehicle 35 Routing Path (P): []
# Clock 588: Vehicle 36 Service Queue (S): []
# Clock 588: Vehicle 36 Routing Path (P): []
# Clock 588: Vehicle 37 Service Queue (S): []
# Clock 588: Vehicle 37 Routing Path (P): []
# Clock 588: Vehicle 38 Service Queue (S): []
# Clock 588: Vehicle 38 Routing Path (P): []
# Clock 588: Vehicle 39 Service Queue (S): []
# Clock 588: Vehicle 39 Routing Path (P): []
# Clock 588: Vehicle 40 Service Queue (S): []
# Clock 588: Vehicle 40 Routing Path (P): []
# Clock 588: Vehicle 41 Service Queue (S): []
# Clock 588: Vehicle 41 Routing Path (P): []
# Clock 588: Vehicle 42 Service Queue (S): []
# Clock 588: Vehicle 42 Routing Path (P): []
# Clock 588: Vehicle 43 Service Queue (S): []
# Clock 588: Vehicle 43 Routing Path (P): []
# Clock 588: Vehicle 44 Service Queue (S): []
# Clock 588: Vehicle 44 Routing Path (P): []
# Clock 588: Vehicle 45 Service Queue (S): []
# Clock 588: Vehicle 45 Routing Path (P): []
# Clock 588: Vehicle 46 Service Queue (S): []
# Clock 588: Vehicle 46 Routing Path (P): []
# Clock 588: Vehicle 47 Service Queue (S): []
# Clock 588: Vehicle 47 Routing Path (P): []
# Clock 588: Vehicle 48 Service Queue (S): []
# Clock 588: Vehicle 48 Routing Path (P): []
# Clock 588: Vehicle 49 Service Queue (S): []
# Clock 588: Vehicle 49 Routing Path (P): []
# Clock 588: Vehicle 50 Service Queue (S): []
# Clock 588: Vehicle 50 Routing Path (P): []
# Clock 588: Vehicle 51 Service Queue (S): []
# Clock 588: Vehicle 51 Routing Path (P): []
# Clock 588: Vehicle 52 Service Queue (S): []
# Clock 588: Vehicle 52 Routing Path (P): []
# Clock 588: Vehicle 53 Service Queue (S): []
# Clock 588: Vehicle 53 Routing Path (P): []
# Clock 588: Vehicle 54 Service Queue (S): []
# Clock 588: Vehicle 54 Routing Path (P): []
# Clock 588: Vehicle 55 Service Queue (S): []
# Clock 588: Vehicle 55 Routing Path (P): []
# Clock 588: Vehicle 56 Service Queue (S): []
# Clock 588: Vehicle 56 Routing Path (P): []
# Clock 588: Vehicle 57 Service Queue (S): []
# Clock 588: Vehicle 57 Routing Path (P): []
# Clock 588: Vehicle 58 Service Queue (S): []
# Clock 588: Vehicle 58 Routing Path (P): []
# Clock 588: Vehicle 59 Service Queue (S): []
# Clock 588: Vehicle 59 Routing Path (P): []
# Dropping off customer at 84 at time 589
# Clock 589: Vehicle 1 Service Queue (S): [(55, 83), (55, 5), (43, 90), (66, 27)]
# Clock 589: Vehicle 1 Routing Path (P): []
# Clock 589: Vehicle 2 Service Queue (S): [(32, 82), (95, 97), (89, 79), (47, 51), (97, 91)]
# Clock 589: Vehicle 2 Routing Path (P): [83, 82]
# Clock 589: Vehicle 3 Service Queue (S): [(35, 97), (39, 94), (94, 72), (2, 38), (83, 28)]
# Clock 589: Vehicle 3 Routing Path (P): [52, 9, 97]
# Clock 589: Vehicle 4 Service Queue (S): [(83, 42), (77, 43), (71, 96), (15, 50), (48, 54)]
# Clock 589: Vehicle 4 Routing Path (P): [42]
# Dropping off customer at 94 at time 589
# Clock 589: Vehicle 5 Service Queue (S): [(79, 98), (3, 54), (32, 79), (32, 88)]
# Clock 589: Vehicle 5 Routing Path (P): [6, 98]
# Dropping off customer at 60 at time 589
# Clock 589: Vehicle 6 Service Queue (S): [(95, 90), (95, 55), (65, 76), (83, 36)]
# Clock 589: Vehicle 6 Routing Path (P): [15, 90]
# Dropping off customer at 36 at time 589
# Dropping off customer at 36 at time 589
# Clock 589: Vehicle 7 Service Queue (S): [(42, 54), (33, 72), (73, 0)]
# Clock 589: Vehicle 7 Routing Path (P): []
# Clock 589: Vehicle 8 Service Queue (S): [(2, 68), (71, 8), (2, 30), (41, 11), (89, 93)]
# Clock 589: Vehicle 8 Routing Path (P): [68]
# Clock 589: Vehicle 9 Service Queue (S): [(2, 95), (51, 14), (83, 33), (31, 77), (55, 37)]
# Clock 589: Vehicle 9 Routing Path (P): [13, 5, 95]
# Clock 589: Vehicle 10 Service Queue (S): [(85, 14), (81, 19), (9, 66), (46, 1), (27, 49)]
# Clock 589: Vehicle 10 Routing Path (P): [60, 14]
# Customer picked up at time 589 by Vehicle 11
# Vehicle 11 moving along path: [19, 45, 7, 65]
# Clock 589: Vehicle 11 Service Queue (S): [(4, 65), (41, 98), (13, 71), (90, 69), (93, 12)]
# Clock 589: Vehicle 11 Routing Path (P): [45, 7, 65]
# Clock 589: Vehicle 12 Service Queue (S): [(48, 55), (23, 73), (75, 91), (26, 11), (87, 54)]
# Clock 589: Vehicle 12 Routing Path (P): [85, 31, 55]
# Clock 589: Vehicle 13 Service Queue (S): [(28, 41), (10, 24), (28, 88), (90, 98), (98, 50)]
# Clock 589: Vehicle 13 Routing Path (P): [37, 41]
# Dropping off customer at 50 at time 589
# Clock 589: Vehicle 14 Service Queue (S): [(99, 54), (54, 36), (34, 32), (61, 66)]
# Clock 589: Vehicle 14 Routing Path (P): []
# Clock 589: Vehicle 15 Service Queue (S): [(8, 32), (33, 97), (98, 32), (63, 51), (30, 14)]
# Clock 589: Vehicle 15 Routing Path (P): [99, 32]
# Dropping off customer at 81 at time 589
# Clock 589: Vehicle 16 Service Queue (S): [(79, 66), (0, 40), (69, 77), (98, 50)]
# Clock 589: Vehicle 16 Routing Path (P): []
# Customer picked up at time 589 by Vehicle 17
# Vehicle 17 moving along path: [35, 11, 92]
# Clock 589: Vehicle 17 Service Queue (S): [(82, 92), (8, 82), (21, 43), (19, 40), (68, 14)]
# Clock 589: Vehicle 17 Routing Path (P): [11, 92]
# Clock 589: Vehicle 18 Service Queue (S): [(37, 90), (5, 39), (92, 72), (38, 42), (61, 16)]
# Clock 589: Vehicle 18 Routing Path (P): [17, 90]
# Dropping off customer at 7 at time 589
# Clock 589: Vehicle 19 Service Queue (S): [(7, 19), (54, 59), (0, 67), (74, 13)]
# Clock 589: Vehicle 19 Routing Path (P): []
# Clock 589: Vehicle 20 Service Queue (S): [(56, 92), (84, 4), (22, 7), (65, 2), (70, 78)]
# Clock 589: Vehicle 20 Routing Path (P): [35, 11, 92]
# Dropping off customer at 53 at time 589
# Clock 589: Vehicle 21 Service Queue (S): [(39, 51), (35, 5), (36, 96), (29, 50)]
# Clock 589: Vehicle 21 Routing Path (P): []
# Clock 589: Vehicle 22 Service Queue (S): [(52, 23), (74, 91), (11, 95), (61, 77), (74, 57)]
# Clock 589: Vehicle 22 Routing Path (P): [34, 23]
# Customer picked up at time 589 by Vehicle 23
# Vehicle 23 moving along path: [5, 95, 31]
# Clock 589: Vehicle 23 Service Queue (S): [(27, 31), (15, 90), (33, 52), (29, 99), (17, 28)]
# Clock 589: Vehicle 23 Routing Path (P): [95, 31]
# Customer picked up at time 589 by Vehicle 24
# Vehicle 24 moving along path: [5, 1, 56, 42, 33]
# Clock 589: Vehicle 24 Service Queue (S): [(0, 33), (12, 74), (92, 32), (47, 49), (81, 35)]
# Clock 589: Vehicle 24 Routing Path (P): [1, 56, 42, 33]
# Clock 589: Vehicle 25 Service Queue (S): [(95, 28), (48, 17), (87, 67), (81, 94), (7, 31)]
# Clock 589: Vehicle 25 Routing Path (P): [75, 28]
# Clock 589: Vehicle 26 Service Queue (S): [(18, 23), (14, 23), (27, 90), (46, 29), (10, 97)]
# Clock 589: Vehicle 26 Routing Path (P): [34, 23]
# Clock 589: Vehicle 27 Service Queue (S): [(31, 14), (96, 90), (64, 80), (63, 60), (57, 90)]
# Clock 589: Vehicle 27 Routing Path (P): [14]
# Customer picked up at time 589 by Vehicle 28
# Vehicle 28 moving along path: [69, 63]
# Clock 589: Vehicle 28 Service Queue (S): [(26, 63), (61, 3), (84, 53), (94, 3), (25, 63)]
# Clock 589: Vehicle 28 Routing Path (P): [63]
# Clock 589: Vehicle 29 Service Queue (S): [(29, 75), (77, 71), (16, 57), (81, 66)]
# Clock 589: Vehicle 29 Routing Path (P): [28, 75]
# Clock 589: Vehicle 30 Service Queue (S): [(19, 43), (19, 87), (13, 70), (44, 58)]
# Clock 589: Vehicle 30 Routing Path (P): [43]
# Clock 589: Vehicle 31 Service Queue (S): [(84, 49), (28, 35), (53, 58), (85, 28)]
# Clock 589: Vehicle 31 Routing Path (P): [87, 49]
# Clock 589: Vehicle 32 Service Queue (S): [(38, 0), (16, 13), (36, 34), (89, 6)]
# Clock 589: Vehicle 32 Routing Path (P): [46, 0]
# Customer picked up at time 589 by Vehicle 33
# Vehicle 33 moving along path: [26, 37, 41, 55]
# Clock 589: Vehicle 33 Service Queue (S): [(17, 55), (94, 17)]
# Clock 589: Vehicle 33 Routing Path (P): [37, 41, 55]
# Clock 589: Vehicle 34 Service Queue (S): []
# Clock 589: Vehicle 34 Routing Path (P): []
# Clock 589: Vehicle 35 Service Queue (S): []
# Clock 589: Vehicle 35 Routing Path (P): []
# Clock 589: Vehicle 36 Service Queue (S): []
# Clock 589: Vehicle 36 Routing Path (P): []
# Clock 589: Vehicle 37 Service Queue (S): []
# Clock 589: Vehicle 37 Routing Path (P): []
# Clock 589: Vehicle 38 Service Queue (S): []
# Clock 589: Vehicle 38 Routing Path (P): []
# Clock 589: Vehicle 39 Service Queue (S): []
# Clock 589: Vehicle 39 Routing Path (P): []
# Clock 589: Vehicle 40 Service Queue (S): []
# Clock 589: Vehicle 40 Routing Path (P): []
# Clock 589: Vehicle 41 Service Queue (S): []
# Clock 589: Vehicle 41 Routing Path (P): []
# Clock 589: Vehicle 42 Service Queue (S): []
# Clock 589: Vehicle 42 Routing Path (P): []
# Clock 589: Vehicle 43 Service Queue (S): []
# Clock 589: Vehicle 43 Routing Path (P): []
# Clock 589: Vehicle 44 Service Queue (S): []
# Clock 589: Vehicle 44 Routing Path (P): []
# Clock 589: Vehicle 45 Service Queue (S): []
# Clock 589: Vehicle 45 Routing Path (P): []
# Clock 589: Vehicle 46 Service Queue (S): []
# Clock 589: Vehicle 46 Routing Path (P): []
# Clock 589: Vehicle 47 Service Queue (S): []
# Clock 589: Vehicle 47 Routing Path (P): []
# Clock 589: Vehicle 48 Service Queue (S): []
# Clock 589: Vehicle 48 Routing Path (P): []
# Clock 589: Vehicle 49 Service Queue (S): []
# Clock 589: Vehicle 49 Routing Path (P): []
# Clock 589: Vehicle 50 Service Queue (S): []
# Clock 589: Vehicle 50 Routing Path (P): []
# Clock 589: Vehicle 51 Service Queue (S): []
# Clock 589: Vehicle 51 Routing Path (P): []
# Clock 589: Vehicle 52 Service Queue (S): []
# Clock 589: Vehicle 52 Routing Path (P): []
# Clock 589: Vehicle 53 Service Queue (S): []
# Clock 589: Vehicle 53 Routing Path (P): []
# Clock 589: Vehicle 54 Service Queue (S): []
# Clock 589: Vehicle 54 Routing Path (P): []
# Clock 589: Vehicle 55 Service Queue (S): []
# Clock 589: Vehicle 55 Routing Path (P): []
# Clock 589: Vehicle 56 Service Queue (S): []
# Clock 589: Vehicle 56 Routing Path (P): []
# Clock 589: Vehicle 57 Service Queue (S): []
# Clock 589: Vehicle 57 Routing Path (P): []
# Clock 589: Vehicle 58 Service Queue (S): []
# Clock 589: Vehicle 58 Routing Path (P): []
# Clock 589: Vehicle 59 Service Queue (S): []
# Clock 589: Vehicle 59 Routing Path (P): []
# Customer picked up at time 590 by Vehicle 1
# Vehicle 1 moving along path: [84, 61, 53, 26, 83]
# Clock 590: Vehicle 1 Service Queue (S): [(55, 83), (55, 5), (43, 90), (66, 27), (12, 38)]
# Clock 590: Vehicle 1 Routing Path (P): [61, 53, 26, 83]
# Clock 590: Vehicle 2 Service Queue (S): [(32, 82), (95, 97), (89, 79), (47, 51), (97, 91)]
# Clock 590: Vehicle 2 Routing Path (P): [82]
# Clock 590: Vehicle 3 Service Queue (S): [(35, 97), (39, 94), (94, 72), (2, 38), (83, 28)]
# Clock 590: Vehicle 3 Routing Path (P): [9, 97]
# Dropping off customer at 42 at time 590
# Clock 590: Vehicle 4 Service Queue (S): [(77, 43), (71, 96), (15, 50), (48, 54)]
# Clock 590: Vehicle 4 Routing Path (P): []
# Clock 590: Vehicle 5 Service Queue (S): [(79, 98), (3, 54), (32, 79), (32, 88), (7, 89)]
# Clock 590: Vehicle 5 Routing Path (P): [98]
# Clock 590: Vehicle 6 Service Queue (S): [(95, 90), (95, 55), (65, 76), (83, 36), (3, 71)]
# Clock 590: Vehicle 6 Routing Path (P): [90]
# Customer picked up at time 590 by Vehicle 7
# Vehicle 7 moving along path: [36, 83, 82, 54]
# Clock 590: Vehicle 7 Service Queue (S): [(42, 54), (33, 72), (73, 0), (88, 96), (73, 3)]
# Clock 590: Vehicle 7 Routing Path (P): [83, 82, 54]
# Dropping off customer at 68 at time 590
# Clock 590: Vehicle 8 Service Queue (S): [(71, 8), (2, 30), (41, 11), (89, 93)]
# Clock 590: Vehicle 8 Routing Path (P): []
# Clock 590: Vehicle 9 Service Queue (S): [(2, 95), (51, 14), (83, 33), (31, 77), (55, 37)]
# Clock 590: Vehicle 9 Routing Path (P): [5, 95]
# Clock 590: Vehicle 10 Service Queue (S): [(85, 14), (81, 19), (9, 66), (46, 1), (27, 49)]
# Clock 590: Vehicle 10 Routing Path (P): [14]
# Clock 590: Vehicle 11 Service Queue (S): [(4, 65), (41, 98), (13, 71), (90, 69), (93, 12)]
# Clock 590: Vehicle 11 Routing Path (P): [7, 65]
# Clock 590: Vehicle 12 Service Queue (S): [(48, 55), (23, 73), (75, 91), (26, 11), (87, 54)]
# Clock 590: Vehicle 12 Routing Path (P): [31, 55]
# Clock 590: Vehicle 13 Service Queue (S): [(28, 41), (10, 24), (28, 88), (90, 98), (98, 50)]
# Clock 590: Vehicle 13 Routing Path (P): [41]
# Customer picked up at time 590 by Vehicle 14
# Vehicle 14 moving along path: [50, 97, 47, 54]
# Clock 590: Vehicle 14 Service Queue (S): [(99, 54), (54, 36), (34, 32), (61, 66), (1, 13)]
# Clock 590: Vehicle 14 Routing Path (P): [97, 47, 54]
# Clock 590: Vehicle 15 Service Queue (S): [(8, 32), (33, 97), (98, 32), (63, 51), (30, 14)]
# Clock 590: Vehicle 15 Routing Path (P): [32]
# Customer picked up at time 590 by Vehicle 16
# Vehicle 16 moving along path: [81, 65, 57, 55, 66]
# Clock 590: Vehicle 16 Service Queue (S): [(79, 66), (0, 40), (69, 77), (98, 50), (87, 73)]
# Clock 590: Vehicle 16 Routing Path (P): [65, 57, 55, 66]
# Clock 590: Vehicle 17 Service Queue (S): [(82, 92), (8, 82), (21, 43), (19, 40), (68, 14)]
# Clock 590: Vehicle 17 Routing Path (P): [92]
# Clock 590: Vehicle 18 Service Queue (S): [(37, 90), (5, 39), (92, 72), (38, 42), (61, 16)]
# Clock 590: Vehicle 18 Routing Path (P): [90]
# Customer picked up at time 590 by Vehicle 19
# Vehicle 19 moving along path: [7, 45, 19]
# Clock 590: Vehicle 19 Service Queue (S): [(7, 19), (54, 59), (0, 67), (74, 13), (68, 48)]
# Clock 590: Vehicle 19 Routing Path (P): [45, 19]
# Clock 590: Vehicle 20 Service Queue (S): [(56, 92), (84, 4), (22, 7), (65, 2), (70, 78)]
# Clock 590: Vehicle 20 Routing Path (P): [11, 92]
# Customer picked up at time 590 by Vehicle 21
# Vehicle 21 moving along path: [53, 7, 24, 51]
# Clock 590: Vehicle 21 Service Queue (S): [(39, 51), (35, 5), (36, 96), (29, 50), (47, 96)]
# Clock 590: Vehicle 21 Routing Path (P): [7, 24, 51]
# Clock 590: Vehicle 22 Service Queue (S): [(52, 23), (74, 91), (11, 95), (61, 77), (74, 57)]
# Clock 590: Vehicle 22 Routing Path (P): [23]
# Clock 590: Vehicle 23 Service Queue (S): [(27, 31), (15, 90), (33, 52), (29, 99), (17, 28)]
# Clock 590: Vehicle 23 Routing Path (P): [31]
# Clock 590: Vehicle 24 Service Queue (S): [(0, 33), (12, 74), (92, 32), (47, 49), (81, 35)]
# Clock 590: Vehicle 24 Routing Path (P): [56, 42, 33]
# Clock 590: Vehicle 25 Service Queue (S): [(95, 28), (48, 17), (87, 67), (81, 94), (7, 31)]
# Clock 590: Vehicle 25 Routing Path (P): [28]
# Clock 590: Vehicle 52 Service Queue (S): []
# Clock 590: Vehicle 52 Routing Path (P): []
# Clock 590: Vehicle 53 Service Queue (S): []
# Clock 590: Vehicle 53 Routing Path (P): []
# Clock 590: Vehicle 54 Service Queue (S): []
# Clock 590: Vehicle 54 Routing Path (P): []
# Clock 590: Vehicle 55 Service Queue (S): []
# Clock 590: Vehicle 55 Routing Path (P): []
# Clock 590: Vehicle 56 Service Queue (S): []
# Clock 590: Vehicle 56 Routing Path (P): []
# Clock 590: Vehicle 57 Service Queue (S): []
# Clock 590: Vehicle 57 Routing Path (P): []
# Clock 590: Vehicle 58 Service Queue (S): []
# Clock 590: Vehicle 58 Routing Path (P): []
# Clock 590: Vehicle 59 Service Queue (S): []
# Clock 590: Vehicle 59 Routing Path (P): []
# Clock 591: Vehicle 1 Service Queue (S): [(55, 83), (55, 5), (43, 90), (66, 27), (12, 38)]
# Clock 591: Vehicle 1 Routing Path (P): [53, 26, 83]
# Dropping off customer at 82 at time 591
# Clock 591: Vehicle 2 Service Queue (S): [(95, 97), (89, 79), (47, 51), (97, 91)]
# Clock 591: Vehicle 2 Routing Path (P): []
# Clock 591: Vehicle 3 Service Queue (S): [(35, 97), (39, 94), (94, 72), (2, 38), (83, 28)]
# Clock 591: Vehicle 3 Routing Path (P): [97]
# Customer picked up at time 591 by Vehicle 4
# Vehicle 4 moving along path: [42, 28, 75, 43]
# Clock 591: Vehicle 4 Service Queue (S): [(77, 43), (71, 96), (15, 50), (48, 54), (24, 94)]
# Clock 591: Vehicle 4 Routing Path (P): [28, 75, 43]
# Dropping off customer at 98 at time 591
# Clock 591: Vehicle 5 Service Queue (S): [(3, 54), (32, 79), (32, 88), (7, 89)]
# Clock 591: Vehicle 5 Routing Path (P): []
# Dropping off customer at 90 at time 591
# Clock 591: Vehicle 6 Service Queue (S): [(95, 55), (65, 76), (83, 36), (3, 71)]
# Clock 591: Vehicle 6 Routing Path (P): []
# Clock 591: Vehicle 7 Service Queue (S): [(42, 54), (33, 72), (73, 0), (88, 96), (73, 3)]
# Clock 591: Vehicle 7 Routing Path (P): [82, 54]
# Customer picked up at time 591 by Vehicle 8
# Vehicle 8 moving along path: [68, 19, 8]
# Clock 591: Vehicle 8 Service Queue (S): [(71, 8), (2, 30), (41, 11), (89, 93), (10, 12)]
# Clock 591: Vehicle 8 Routing Path (P): [19, 8]
# Clock 591: Vehicle 9 Service Queue (S): [(2, 95), (51, 14), (83, 33), (31, 77), (55, 37)]
# Clock 591: Vehicle 9 Routing Path (P): [95]
# Dropping off customer at 14 at time 591
# Clock 591: Vehicle 10 Service Queue (S): [(81, 19), (9, 66), (46, 1), (27, 49)]
# Clock 591: Vehicle 10 Routing Path (P): []
# Clock 591: Vehicle 11 Service Queue (S): [(4, 65), (41, 98), (13, 71), (90, 69), (93, 12)]
# Clock 591: Vehicle 11 Routing Path (P): [65]
# Clock 591: Vehicle 12 Service Queue (S): [(48, 55), (23, 73), (75, 91), (26, 11), (87, 54)]
# Clock 591: Vehicle 12 Routing Path (P): [55]
# Dropping off customer at 41 at time 591
# Clock 619: Vehicle 58 Routing Path (P): []
# Clock 619: Vehicle 59 Service Queue (S): []
# Clock 619: Vehicle 59 Routing Path (P): []
# Clock 620: Vehicle 1 Service Queue (S): []
# Clock 620: Vehicle 1 Routing Path (P): []
# Clock 620: Vehicle 2 Service Queue (S): []
# Clock 620: Vehicle 2 Routing Path (P): []
# Clock 620: Vehicle 3 Service Queue (S): []
# Clock 620: Vehicle 3 Routing Path (P): []
# Clock 620: Vehicle 4 Service Queue (S): []
# Clock 620: Vehicle 4 Routing Path (P): []
# Clock 620: Vehicle 5 Service Queue (S): []
# Clock 620: Vehicle 5 Routing Path (P): []
# Clock 620: Vehicle 6 Service Queue (S): []
# Clock 620: Vehicle 6 Routing Path (P): []
# Clock 620: Vehicle 7 Service Queue (S): []
# Clock 620: Vehicle 7 Routing Path (P): []
# Clock 620: Vehicle 8 Service Queue (S): []
# Clock 620: Vehicle 8 Routing Path (P): []
# Clock 620: Vehicle 9 Service Queue (S): []
# Clock 620: Vehicle 9 Routing Path (P): []
# Clock 620: Vehicle 10 Service Queue (S): []
# Clock 620: Vehicle 10 Routing Path (P): []
# Clock 620: Vehicle 11 Service Queue (S): []
# Clock 620: Vehicle 11 Routing Path (P): []
# Dropping off customer at 92 at time 620
# Clock 620: Vehicle 12 Service Queue (S): []
# Clock 620: Vehicle 12 Routing Path (P): []
# Clock 620: Vehicle 13 Service Queue (S): []
# Clock 620: Vehicle 13 Routing Path (P): []
# Dropping off customer at 59 at time 620
# Clock 620: Vehicle 14 Service Queue (S): []
# Clock 620: Vehicle 14 Routing Path (P): []
# Clock 620: Vehicle 15 Service Queue (S): []
# Clock 620: Vehicle 15 Routing Path (P): []
# Clock 620: Vehicle 16 Service Queue (S): []
# Clock 620: Vehicle 16 Routing Path (P): []
# Clock 620: Vehicle 17 Service Queue (S): []
# Clock 620: Vehicle 17 Routing Path (P): []
# Clock 620: Vehicle 18 Service Queue (S): []
# Clock 620: Vehicle 18 Routing Path (P): []
# Clock 620: Vehicle 19 Service Queue (S): []
# Clock 620: Vehicle 19 Routing Path (P): []
# Clock 620: Vehicle 20 Service Queue (S): []
# Clock 620: Vehicle 20 Routing Path (P): []
# Clock 620: Vehicle 21 Service Queue (S): []
# Clock 620: Vehicle 21 Routing Path (P): []
# Clock 620: Vehicle 22 Service Queue (S): []
# Clock 620: Vehicle 22 Routing Path (P): []
# Clock 620: Vehicle 23 Service Queue (S): []
# Clock 620: Vehicle 23 Routing Path (P): []
# Clock 620: Vehicle 24 Service Queue (S): []
# Clock 620: Vehicle 24 Routing Path (P): []
# Clock 620: Vehicle 25 Service Queue (S): []
# Clock 620: Vehicle 25 Routing Path (P): []
# Clock 620: Vehicle 26 Service Queue (S): []
# Clock 620: Vehicle 26 Routing Path (P): []
# Clock 620: Vehicle 27 Service Queue (S): []
# Clock 620: Vehicle 27 Routing Path (P): []
# Clock 620: Vehicle 28 Service Queue (S): []
# Clock 620: Vehicle 28 Routing Path (P): []
# Clock 620: Vehicle 29 Service Queue (S): []
# Clock 620: Vehicle 29 Routing Path (P): []
